# %%
import pandas as pd
import numpy as np 
from sklearn.preprocessing import OneHotEncoder
import tensorflow.keras as keras
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Dense, Activation, Dropout, LSTM, Bidirectional,SimpleRNN,GRU
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import os
from keras.layers import Input, LSTM, Embedding, Dense
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM, Dropout
from keras.callbacks import LambdaCallback
from keras.layers import TimeDistributed
from keras.optimizers import RMSprop
from keras.utils import plot_model
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras import layers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/imdb.csv')

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

# %%
def preporcessing(df):
    for i in range(len(df)):
        df['review'].iloc[i] = df['review'].iloc[i].replace('<br />','')
        df['review'].iloc[i] = df['review'].iloc[i].lower()
    return df
        
df = preporcessing(df)

# %%
df
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production. the filming tec...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically there's a family where a little boy ...  negative
# 4      petter mattei's "love in the time of money" is...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  i'm going to have to disagree with the previou...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
df['review'].fillna('').apply(lambda x:len(x.split())).max()
# Out:
# 2450

# %%
X = df['review']
y = df['sentiment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, shuffle=True)

# %%
X_train.fillna('').apply(lambda x:len(x.split())).max()
# Out:
# 2450

# %%
X_test.fillna('').apply(lambda x:len(x.split())).max()
# Out:
# 1709

# %%
X_train = X_train.values
X_test = X_test.values

# %%
y_train = y_train.apply(lambda x:1 if x=='positive' else 0)
y_test = y_test.apply(lambda x:1 if x=='positive' else 0)

# %%
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(X_train)

# %%
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
vocab_size = len(tokenizer.word_index) + 1

# %%
maxlen = 2500
X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

# %%
X_train # note: this is different every time
# Out:
# array([[1111,  756,    8, ...,    0,    0,    0],
#        [   1,    4,   10, ...,    0,    0,    0],
#        [1441,  951,    6, ...,    0,    0,    0],
#        ...,
#        [1301,   11,  251, ...,    0,    0,    0],
#        [ 825,    1, 1161, ...,    0,    0,    0],
#        [   1, 3511,    6, ...,    0,    0,    0]], dtype=int32)

# %%
np.mean(y_train)
# Out:
# 0.49945

# %%
embedding_dim = 50

model_1 = Sequential()
model_1.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim, 
                           input_length=maxlen))
model_1.add(layers.Flatten())
model_1.add(layers.Dense(10, activation='relu'))
model_1.add(layers.Dense(1, activation='sigmoid'))
model_1.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 2500, 50)          5705250
#
#  flatten_1 (Flatten)         (None, 125000)            0
#
#  dense_2 (Dense)             (None, 10)                1250010
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 6,955,271
# Trainable params: 6,955,271
# Non-trainable params: 0
# _________________________________________________________________

# %%
history   = model_1.fit(X_train, y_train,
                    epochs=10,
                    verbose=True,
                    validation_data=(X_test, y_test),
                    batch_size=50)
loss, accuracy = model_1.evaluate(X_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
# loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
plot_history(history)
# Out:
# Epoch 1/10
# 800/800 [==============================] - 90s 112ms/step - loss: 0.3824 - accuracy: 0.8235 - val_loss: 0.2783 - val_accuracy: 0.8846
# Epoch 2/10
# 800/800 [==============================] - 90s 112ms/step - loss: 0.2042 - accuracy: 0.9215 - val_loss: 0.2754 - val_accuracy: 0.8923
# Epoch 3/10
# 800/800 [==============================] - 88s 110ms/step - loss: 0.0947 - accuracy: 0.9715 - val_loss: 0.3427 - val_accuracy: 0.8825
# Epoch 4/10
# 800/800 [==============================] - 91s 114ms/step - loss: 0.0243 - accuracy: 0.9961 - val_loss: 0.4134 - val_accuracy: 0.8797
# Epoch 5/10
# 800/800 [==============================] - 90s 113ms/step - loss: 0.0055 - accuracy: 0.9995 - val_loss: 0.4547 - val_accuracy: 0.8814
# Epoch 6/10
# 800/800 [==============================] - 90s 112ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5339 - val_accuracy: 0.8835
# Epoch 7/10
# 800/800 [==============================] - 90s 112ms/step - loss: 5.3712e-04 - accuracy: 1.0000 - val_loss: 0.5744 - val_accuracy: 0.8845
# Epoch 8/10
# 800/800 [==============================] - 88s 111ms/step - loss: 2.6920e-04 - accuracy: 1.0000 - val_loss: 0.6134 - val_accuracy: 0.8856
# Epoch 9/10
# 800/800 [==============================] - 91s 114ms/step - loss: 1.4525e-04 - accuracy: 1.0000 - val_loss: 0.6523 - val_accuracy: 0.8857
# Epoch 10/10
# 800/800 [==============================] - 90s 113ms/step - loss: 8.0002e-05 - accuracy: 1.0000 - val_loss: 0.6947 - val_accuracy: 0.8840
# Training Accuracy: 1.0000
# Testing Accuracy:  1.0000

# %%
embedding_dim = 50
shortenlen = 500

model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim, 
                           input_length=shortenlen))
# model.add(layers.Embedding(input_dim = 500, output_dim=embedding_dim))
model.add(layers.Masking(mask_value=0.0, input_shape=(None,embedding_dim)))
model.add(layers.LSTM(50,activation='relu'))

model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()

history = model.fit(X_train[:,:shortenlen], y_train,
                    epochs=2,
                    # verbose=True,
                    validation_data=(X_test[:,:shortenlen], y_test))#,
                    # batch_size=50)
loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
plot_history(history)
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 500, 50)           5705250
#
#  masking_11 (Masking)        (None, 500, 50)           0
#
#  lstm_9 (LSTM)               (None, 50)                20200
#
#  dense_10 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 5,725,501
# Trainable params: 5,725,501
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
#  756/1250 [=================>............] - ETA: 2:51 - loss: nan - accuracy: 0.4980
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-724f942eb389> in <module>
#      19                     epochs=2,
#      20                     # verbose=True,
# ---> 21                     validation_data=(X_test[:,:shortenlen], y_test))#,
#      22                     # batch_size=50)
#      23 loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453     return graph_function._call_flat(
# -> 2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#    2456   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1859       # No tape is watching; skip to running the function.
#    1860       return self._build_call_outputs(self._inference_function.call(
# -> 1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#    1863         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     500               inputs=args,
#     501               attrs=attrs,
# --> 502               ctx=ctx)
#     503         else:
#     504           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.imdb.com/title/tt0468569/reviews/_ajax?ref_=undefined&paginationKey='

# %%
result = requests.get(url)

# %%
doc = BeautifulSoup(result.text,'html.parser')
div_all = doc.find_all('div')
div_all[4]
# Out:
# <div class="lister-item-content">
# <a class="title" href="/review/rw5478826/"> The Dark Knight
# </a> <div class="display-name-date">
# <span class="display-name-link"><a href="/user/ur87850731/">MR-ODIN</a></span><span class="review-date">12 February 2020</span>
# </div>
# <div class="content">
# <div class="text show-more__control">Confidently directed, dark, brooding, and packed with impressive action sequences and a complex story, The Dark Knight includes a career-defining turn from Heath Ledger as well as other Oscar worthy performances, TDK remains not only the best Batman movie, but comic book movie ever created.</div>
# <div class="actions text-muted">
#                     485 out of 525 found this helpful.
#                         <span>
#                             Was this review helpful? <a href="/registration/signin"> Sign in</a> to vote.
#                         </span>
# <br/>
# <a href="/review/rw5478826/">Permalink</a>
# </div>
# </div>
# </div>

# %%
import os
 
# Get the list of all files and directories
# path = "C:/Users/Neelesh Reddypelli/Documents/3rd Semester/DeepLearning/Projects/2_reviews_per_movie_raw"
path = "/content/drive/MyDrive/Deep-Learning-Movie-Reviews/2_reviews_per_movie_raw"
dir_list = os.listdir(path)
 
print("Files and directories in '", path, "' :")
 
# prints all files
for i in range(len(dir_list)):
    
    
    dir_list[i] = dir_list[i].replace('.csv','')
    dir_list[i] = dir_list[i][:len(dir_list[i]) - 5]
    
    
print(len(dir_list))
# Out:
# Files and directories in ' /content/drive/MyDrive/Deep-Learning-Movie-Reviews/2_reviews_per_movie_raw ' :
# 47

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/Deep-Learning-Movie-Reviews/10 Cloverfield Lane 2016.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-3169b1ec35e9> in <module>
# ----> 1 df_1 = pd.read_csv('/content/drive/MyDrive/Deep-Learning-Movie-Reviews/10 Cloverfield Lane 2016.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Deep-Learning-Movie-Reviews/10 Cloverfield Lane 2016.csv'

# %%
i=1
df{i} = 'df'+str(i)+''

# %%
df_1
# Out:
#             username rating  helpful  total             date  \
# 0      Imme-van-Gorp      7      102    123  30 January 2019
# 1      sonofocelot-1      5      385    500      10 May 2016
# 2            mhodaee      5      110    143    4 August 2017
# 3          fil-nik09      5       73    100   5 October 2016
# 4          DVR_Brale      7       42     56     27 July 2016
# ..               ...    ...      ...    ...              ...
# 747  maurice_yacowar      8        0      2    13 March 2016
# 748     stevendbeard      7        0      3    11 March 2016
# 749      jmoneyjohal      7        0      3    11 March 2016
# 750         MattBirk      8        0      2    11 March 2016
# 751  waltermwilliams      7        0      3    11 March 2016
#
#                                                  title  \
# 0     Unfortunately the ending ruined an otherwise ...
# 1                          ...oh dear Abrams. Again.\n
# 2     Fantastic, gripping, thoroughly enjoyable, un...
# 3                                            Hmmm...\n
# 4     Slow building & plot alternating claustrophob...
# ..                                                 ...
# 747   Resourceful woman survives villain and monster\n
# 748                 Related, But Not Really A Sequel\n
# 749   A good psychological thriller about the unkno...
# 750   An amazing mystery thriller, undermined by it...
# 751   Not even Bovines are safe in Dan Trachtenberg...
#
#                                                 review
# 0    This movie is full of suspense. It makes you g...
# 1    I'll leave this review fairly concise. <br/><b...
# 2    I give the 5/10 out of the credit I owe to the...
# 3    First of all, I must say that I was expecting ...
# 4    I've always loved movies with strong atmospher...
# ..                                                 ...
# 747  Just because you're paranoid doesn't mean the ...
# 748  I saw "10 Cloverfield Lane", starring John Goo...
# 749  10 Cloverfield Lane,is what I classify as a fi...
# 750  I'll get this out of the way early, I firmly b...
# 751  Women imagine spinning out of control in a car...
#
# [752 rows x 7 columns]

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
action = pd.read_csv('movies_reviews\Action.csv')

# %%
action
# Out:
#                                                  name  year movie_rated  \
# 0                                     The Dark Knight  2008       PG-13
# 1                                           Inception  2010       PG-13
# 2                                          The Matrix  1999           R
# 3   The Lord of the Rings: The Fellowship of the Ring  2001       PG-13
# 4                               The Dark Knight Rises  2012       PG-13
# ..                                                ...   ...         ...
# 95          Harry Potter and the Order of the Phoenix  2007       PG-13
# 96                             Spider-Man: Homecoming  2017       PG-13
# 97                     Rise of the Planet of the Apes  2011       PG-13
# 98                                           I, Robot  2004       PG-13
# 99                                           Watchmen  2009           R
#
#    run_length                       genres            release_date  rating  \
# 0    2h 32min       Action; Crime; Drama;       18 July 2008 (USA)     9.0
# 1    2h 28min  Action; Adventure; Sci-Fi;       16 July 2010 (USA)     8.8
# 2    2h 16min             Action; Sci-Fi;      31 March 1999 (USA)     8.7
# 3    2h 58min   Action; Adventure; Drama;   19 December 2001 (USA)     8.8
# 4    2h 44min          Action; Adventure;       20 July 2012 (USA)     8.4
# ..        ...                          ...                     ...     ...
# 95   2h 18min          Action; Adventure;       11 July 2007 (USA)     7.5
# 96   2h 13min  Action; Adventure; Sci-Fi;        7 July 2017 (USA)     7.4
# 97   1h 45min      Action; Drama; Sci-Fi;      5 August 2011 (USA)     7.6
# 98   1h 55min      Action; Drama; Sci-Fi;       16 July 2004 (USA)     7.1
# 99   2h 42min     Action; Drama; Mystery;       6 March 2009 (USA)     7.6
#
#     num_raters  num_reviews                                         review_url
# 0      2224522         6836  https://www.imdb.com/title/tt0468569/reviews/_...
# 1      1981675         3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 2      1619761         4281  https://www.imdb.com/title/tt0133093/reviews/_...
# 3      1609165         5365  https://www.imdb.com/title/tt0120737/reviews/_...
# 4      1470329         2979  https://www.imdb.com/title/tt1345836/reviews/_...
# ..         ...          ...                                                ...
# 95      489759         1189  https://www.imdb.com/title/tt0373889/reviews/_...
# 96      488794         1356  https://www.imdb.com/title/tt2250912/reviews/_...
# 97      488748          706  https://www.imdb.com/title/tt1318514/reviews/_...
# 98      488324          839  https://www.imdb.com/title/tt0343818/reviews/_...
# 99      487717         1398  https://www.imdb.com/title/tt0409459/reviews/_...
#
# [100 rows x 10 columns]

# %%
action = list(action['name']) 
for i in range(len(action)):
    action[i] = action[i].replace(':','_')

# %%
len(action)
# Out:
# 100

# %%
[i for i in action if i in dir_list]
# Out:
# ['The Dark Knight',
#  'Inception',
#  'The Matrix',
#  'The Lord of the Rings_ The Fellowship of the Ring',
#  'The Dark Knight Rises',
#  'Gladiator',
#  'Batman Begins',
#  'The Avengers',
#  'Star Wars_ Episode IV - A New Hope',
#  'Star Wars_ Episode V - The Empire Strikes Back',
#  'Avatar',
#  'Guardians of the Galaxy',
#  'V for Vendetta',
#  'Léon_ The Professional',
#  'Pirates of the Caribbean_ The Curse of the Black Pearl',
#  'Kill Bill_ Vol. 1',
#  'Terminator 2_ Judgment Day',
#  'Star Wars_ Episode VI - Return of the Jedi',
#  'Iron Man',
#  'Deadpool',
#  'Raiders of the Lost Ark',
#  'Mad Max_ Fury Road',
#  'Star Wars_ Episode VII - The Force Awakens',
#  'Jurassic Park',
#  'The Hunger Games',
#  'Avengers_ Infinity War',
#  'The Terminator',
#  'Die Hard',
#  'Avengers_ Endgame',
#  'Iron Man 3',
#  'Thor',
#  '300',
#  'Captain America_ The First Avenger',
#  'Avengers_ Age of Ultron',
#  'Captain America_ The Winter Soldier',
#  'Star Wars_ Episode I - The Phantom Menace',
#  'Iron Man 2',
#  'Star Wars_ Episode III - Revenge of the Sith',
#  'The Revenant',
#  'Man of Steel',
#  'Blade Runner',
#  'Indiana Jones and the Last Crusade',
#  'Spider-Man',
#  'I Am Legend',
#  'Kill Bill_ Vol. 2',
#  'X-Men_ Days of Future Past',
#  'How to Train Your Dragon',
#  "Pirates of the Caribbean_ Dead Man's Chest",
#  'The Incredibles',
#  'Captain America_ Civil War',
#  'Aliens',
#  'X-Men_ First Class',
#  'District 9',
#  'Star Wars_ Episode II - Attack of the Clones',
#  'Logan',
#  'Skyfall',
#  'Batman v Superman_ Dawn of Justice',
#  'The Hunger Games_ Catching Fire',
#  'The Bourne Ultimatum',
#  'Black Panther',
#  'Transformers',
#  'World War Z',
#  "Pirates of the Caribbean_ At World's End",
#  'Suicide Squad',
#  'Edge of Tomorrow',
#  'Thor_ The Dark World',
#  'Kingsman_ The Secret Service',
#  'Doctor Strange',
#  'Sherlock Holmes',
#  'Star Trek',
#  'Casino Royale',
#  'Jurassic World',
#  'X-Men',
#  'Thor_ Ragnarok',
#  'Taken',
#  'Ant-Man',
#  'The Amazing Spider-Man',
#  'Guardians of the Galaxy Vol. 2',
#  'Star Wars_ Episode VIII - The Last Jedi',
#  'Rogue One_ A Star Wars Story',
#  'Wonder Woman',
#  'Spider-Man 2',
#  'Looper',
#  'Dunkirk',
#  'Lock, Stock and Two Smoking Barrels',
#  'Independence Day',
#  'Kick-Ass',
#  'John Wick',
#  'Men in Black',
#  'The Matrix Reloaded',
#  'X2_ X-Men United',
#  '21 Jump Street',
#  'Oldboy',
#  'The Bourne Identity',
#  'Minority Report',
#  'Harry Potter and the Order of the Phoenix',
#  'Spider-Man_ Homecoming',
#  'Rise of the Planet of the Apes',
#  'I, Robot',
#  'Watchmen']

# %%
df = pd.read_csv('/content/drive/MyDrive/imdb.csv')

# %%
# reviews is a pandas series
def preprocess_reviews(reviews):
  reviews_processed = reviews.str.replace('<br />','')
  reviews_processed = reviews.str.lower()
  return reviews_processed

df['review'] = preprocess_reviews(df['review'])

X = df['review'].values
y = df['sentiment'].apply(lambda x:1 if x=='positive' else 0)

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, shuffle=True)

tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(X_train)

X_train_token = tokenizer.texts_to_sequences(X_train)
X_test_token = tokenizer.texts_to_sequences(X_test)

vocab_size = len(tokenizer.word_index) + 1

# %%
maxlen = 100
X_train = pad_sequences(X_train_token, padding='pre', maxlen=maxlen)
X_test = pad_sequences(X_test_token, padding='pre', maxlen=maxlen)

embedding_dim = 50

model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim, 
                           input_length=maxlen))
model.add(layers.LSTM(50,activation='relu'))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()

history = model.fit(X_train, y_train,
                    epochs=2,
                    # verbose=True,
                    validation_data=(X_test, y_test))#,
                    # batch_size=50)
loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
plot_history(history)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 50)           5610350
#
#  lstm (LSTM)                 (None, 50)                20200
#
#  dense (Dense)               (None, 10)                510
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 5,631,071
# Trainable params: 5,631,071
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 1250/1250 [==============================] - 142s 111ms/step - loss: 535882.3125 - accuracy: 0.6849 - val_loss: 7.3161 - val_accuracy: 0.7107
# Epoch 2/2
# 1250/1250 [==============================] - 116s 93ms/step - loss: 20.4896 - accuracy: 0.7485 - val_loss: 10.8408 - val_accuracy: 0.7346
# Training Accuracy: 0.7777
# Testing Accuracy:  0.7346
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-212d682efe15> in <module>
#      26 loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
#      27 print("Testing Accuracy:  {:.4f}".format(accuracy))
# ---> 28 plot_history(history)
#
# NameError: name 'plot_history' is not defined

# %%
maxlen = 100
X_train = pad_sequences(X_train_token, padding='pre', maxlen=maxlen)
X_test = pad_sequences(X_test_token, padding='pre', maxlen=maxlen)

embedding_dim = 50

model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim, 
                           input_length=maxlen))
model.add(layers.LSTM(50,activation='relu'))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()

history = model.fit(X_train, y_train,
                    epochs=5,
                    # verbose=True,
                    validation_data=(X_test, y_test))#,
                    # batch_size=50)
loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
plot_history(history)
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_18 (Embedding)    (None, 100, 50)           5722800
#
#  lstm_18 (LSTM)              (None, 50)                20200
#
#  dense_22 (Dense)            (None, 10)                510
#
#  dense_23 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 5,743,521
# Trainable params: 5,743,521
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1250/1250 [==============================] - 140s 111ms/step - loss: 58458.2266 - accuracy: 0.6982 - val_loss: 0.5711 - val_accuracy: 0.7275
# Epoch 2/5
# 1250/1250 [==============================] - 130s 104ms/step - loss: 22922917888.0000 - accuracy: 0.7570 - val_loss: 15694.9502 - val_accuracy: 0.7486
# Epoch 3/5
# 1250/1250 [==============================] - 131s 105ms/step - loss: 1923798.8750 - accuracy: 0.7696 - val_loss: 0.5408 - val_accuracy: 0.7213
# Epoch 4/5
# 1250/1250 [==============================] - 132s 105ms/step - loss: 3336.5139 - accuracy: 0.7600 - val_loss: 0.5485 - val_accuracy: 0.7139
# Epoch 5/5
# 1250/1250 [==============================] - 132s 105ms/step - loss: 0.4936 - accuracy: 0.7638 - val_loss: 0.5469 - val_accuracy: 0.7171
# Training Accuracy: 0.7761
# Testing Accuracy:  0.7171

# %%
maxlen = 100
X_train = pad_sequences(X_train_token, padding='pre', maxlen=maxlen)
X_test = pad_sequences(X_test_token, padding='pre', maxlen=maxlen)

embedding_dim = 50

model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim, 
                           input_length=maxlen))
model.add(layers.SimpleRNN(50,activation='relu'))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()

history = model.fit(X_train, y_train,
                    epochs=5,
                    # verbose=True,
                    validation_data=(X_test, y_test))#,
                    # batch_size=50)
loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
plot_history(history)
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_19 (Embedding)    (None, 100, 50)           5722800
#
#  simple_rnn (SimpleRNN)      (None, 50)                5050
#
#  dense_24 (Dense)            (None, 10)                510
#
#  dense_25 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 5,728,371
# Trainable params: 5,728,371
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1250/1250 [==============================] - 112s 87ms/step - loss: 0.4446 - accuracy: 0.7843 - val_loss: 0.3582 - val_accuracy: 0.8485
# Epoch 2/5
# 1250/1250 [==============================] - 107s 85ms/step - loss: 0.3134 - accuracy: 0.8686 - val_loss: 0.3245 - val_accuracy: 0.8592
# Epoch 3/5
# 1250/1250 [==============================] - 105s 84ms/step - loss: 0.2806 - accuracy: 0.8842 - val_loss: 0.3299 - val_accuracy: 0.8575
# Epoch 4/5
# 1250/1250 [==============================] - 104s 83ms/step - loss: 0.2465 - accuracy: 0.9001 - val_loss: 0.3397 - val_accuracy: 0.8580
# Epoch 5/5
# 1250/1250 [==============================] - 106s 84ms/step - loss: 0.2407 - accuracy: 0.9028 - val_loss: 0.3507 - val_accuracy: 0.8583
# Training Accuracy: 0.9342
# Testing Accuracy:  0.8583

# %%
maxlen = 100
X_train = pad_sequences(X_train_token, padding='pre', maxlen=maxlen)
X_test = pad_sequences(X_test_token, padding='pre', maxlen=maxlen)

embedding_dim = 50

model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim, 
                           input_length=maxlen))
model.add(layers.GRU(50,activation='relu'))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()

history = model.fit(X_train, y_train,
                    epochs=5,
                    # verbose=True,
                    validation_data=(X_test, y_test))#,
                    # batch_size=50)
loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
plot_history(history)
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 100, 50)           5711350
#
#  gru (GRU)                   (None, 50)                15300
#
#  dense_8 (Dense)             (None, 10)                510
#
#  dense_9 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 5,727,171
# Trainable params: 5,727,171
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1250/1250 [==============================] - 136s 108ms/step - loss: 0.4850 - accuracy: 0.7604 - val_loss: 0.3583 - val_accuracy: 0.8519
# Epoch 2/5
# 1250/1250 [==============================] - 141s 112ms/step - loss: 0.3043 - accuracy: 0.8722 - val_loss: 0.3406 - val_accuracy: 0.8551
# Epoch 3/5
# 1250/1250 [==============================] - 133s 106ms/step - loss: 0.2582 - accuracy: 0.8933 - val_loss: 0.3284 - val_accuracy: 0.8549
# Epoch 4/5
# 1250/1250 [==============================] - 135s 108ms/step - loss: 0.2213 - accuracy: 0.9122 - val_loss: 0.3539 - val_accuracy: 0.8570
# Epoch 5/5
# 1250/1250 [==============================] - 153s 123ms/step - loss: 0.1958 - accuracy: 0.9237 - val_loss: 0.3472 - val_accuracy: 0.8567
# Training Accuracy: 0.9517
# Testing Accuracy:  0.8567

# %%
maxlen = 200
X_train = pad_sequences(X_train_token, padding='pre', maxlen=maxlen)
X_test = pad_sequences(X_test_token, padding='pre', maxlen=maxlen)

embedding_dim = 50

model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim, 
                           input_length=maxlen))
model.add(layers.GRU(50,activation='relu'))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()

history = model.fit(X_train, y_train,
                    epochs=5,
                    # verbose=True, 
                    validation_data=(X_test, y_test))#,
                    # batch_size=50)
loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
plot_history(history)
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 200, 50)           5628250
#
#  gru (GRU)                   (None, 50)                15300
#
#  dense (Dense)               (None, 10)                510
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 5,644,071
# Trainable params: 5,644,071
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1250/1250 [==============================] - 238s 188ms/step - loss: 0.5755 - accuracy: 0.7499 - val_loss: 0.3598 - val_accuracy: 0.8435
# Epoch 2/5
# 1250/1250 [==============================] - 233s 187ms/step - loss: 0.2886 - accuracy: 0.8795 - val_loss: 0.2958 - val_accuracy: 0.8764
# Epoch 3/5
# 1250/1250 [==============================] - 247s 198ms/step - loss: 0.2321 - accuracy: 0.9078 - val_loss: 0.2888 - val_accuracy: 0.8814
# Epoch 4/5
# 1250/1250 [==============================] - 234s 187ms/step - loss: 0.2025 - accuracy: 0.9203 - val_loss: 0.2887 - val_accuracy: 0.8805
# Epoch 5/5
# 1250/1250 [==============================] - 235s 188ms/step - loss: 0.1706 - accuracy: 0.9350 - val_loss: 0.3019 - val_accuracy: 0.8834
# Training Accuracy: 0.9583
# Testing Accuracy:  0.8834

# %%
maxlen = 300
X_train = pad_sequences(X_train_token, padding='pre', maxlen=maxlen)
X_test = pad_sequences(X_test_token, padding='pre', maxlen=maxlen)

embedding_dim = 50

model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim, 
                           input_length=maxlen))
model.add(layers.GRU(50,activation='relu'))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()

history = model.fit(X_train, y_train,
                    epochs=10,
                    # verbose=True, 
                    validation_data=(X_test, y_test))#,
                    # batch_size=50)
loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
plot_history(history)
# Out:
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 300, 50)           5613550
#
#  gru_1 (GRU)                 (None, 50)                15300
#
#  dense_2 (Dense)             (None, 10)                510
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 5,629,371
# Trainable params: 5,629,371
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1250/1250 [==============================] - 358s 286ms/step - loss: 111146240.0000 - accuracy: 0.7180 - val_loss: 0.3400 - val_accuracy: 0.8587
# Epoch 2/10
# 1250/1250 [==============================] - 357s 285ms/step - loss: 0.3017 - accuracy: 0.8767 - val_loss: 0.3049 - val_accuracy: 0.8743
# Epoch 3/10
# 1250/1250 [==============================] - 356s 284ms/step - loss: 0.2572 - accuracy: 0.8970 - val_loss: 0.3200 - val_accuracy: 0.8725
# Epoch 4/10
# 1250/1250 [==============================] - 365s 292ms/step - loss: 0.2379 - accuracy: 0.9058 - val_loss: 0.3081 - val_accuracy: 0.8721
# Epoch 5/10
# 1250/1250 [==============================] - 367s 294ms/step - loss: 0.2219 - accuracy: 0.9141 - val_loss: 0.3168 - val_accuracy: 0.8706
# Epoch 6/10
# 1250/1250 [==============================] - 372s 298ms/step - loss: 0.2092 - accuracy: 0.9176 - val_loss: 0.3251 - val_accuracy: 0.8682
# Epoch 7/10
# 1250/1250 [==============================] - 368s 294ms/step - loss: 0.1970 - accuracy: 0.9237 - val_loss: 0.3418 - val_accuracy: 0.8640
# Epoch 8/10
# 1250/1250 [==============================] - 365s 292ms/step - loss: 0.1875 - accuracy: 0.9290 - val_loss: 0.3543 - val_accuracy: 0.8643
# Epoch 9/10
# 1250/1250 [==============================] - 368s 294ms/step - loss: 0.1819 - accuracy: 0.9308 - val_loss: 0.3486 - val_accuracy: 0.8632
# Epoch 10/10
# 1250/1250 [==============================] - 366s 293ms/step - loss: 0.1725 - accuracy: 0.9353 - val_loss: 0.3751 - val_accuracy: 0.8642
# Training Accuracy: 0.9457
# Testing Accuracy:  0.8642

# %%
111maxlen = 50
X_train = pad_sequences(X_train_token, padding='pre', maxlen=maxlen)
X_test = pad_sequences(X_test_token, padding='pre', maxlen=maxlen)

embedding_dim = 50

model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim, 
                           input_length=maxlen))
model.add(layers.SimpleRNN(50,activation='relu'))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()

history = model.fit(X_train, y_train,
                    epochs=5,
                    # verbose=True,
                    validation_data=(X_test, y_test))#,
                    # batch_size=50)
loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
plot_history(history)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 50, 50)            5610350
#
#  simple_rnn (SimpleRNN)      (None, 50)                5050
#
#  dense_4 (Dense)             (None, 10)                510
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 5,615,921
# Trainable params: 5,615,921
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1250/1250 [==============================] - 47s 37ms/step - loss: 0.4660 - accuracy: 0.7688 - val_loss: 0.4130 - val_accuracy: 0.8080
# Epoch 2/5
# 1250/1250 [==============================] - 44s 35ms/step - loss: 0.3512 - accuracy: 0.8454 - val_loss: 0.3812 - val_accuracy: 0.8258
# Epoch 3/5
# 1250/1250 [==============================] - 44s 35ms/step - loss: 0.3038 - accuracy: 0.8694 - val_loss: 0.3882 - val_accuracy: 0.8205
# Epoch 4/5
# 1250/1250 [==============================] - 46s 37ms/step - loss: 0.2588 - accuracy: 0.8929 - val_loss: 0.4245 - val_accuracy: 0.8176
# Epoch 5/5
# 1250/1250 [==============================] - 44s 35ms/step - loss: 0.2191 - accuracy: 0.9104 - val_loss: 0.4378 - val_accuracy: 0.8238
# Training Accuracy: 0.9369
# Testing Accuracy:  0.8238
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-7bd879f4141e> in <module>
#      26 loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
#      27 print("Testing Accuracy:  {:.4f}".format(accuracy))
# ---> 28 plot_history(history)
#
# NameError: name 'plot_history' is not defined

# %%
movie_df = pd.read_csv('/content/drive/MyDrive/Deep-Learning-Movie-Reviews/2_reviews_per_movie_raw/50_50 2011.csv')

# %%
# reviews: np vector of reviews (in text form)
# model: a keras model
### returns: flattened np array of predictions (1 for positive, 0 for negative) 
def predict_pos(reviews, model):
  X = preprocess_reviews(reviews).values
  X_token = tokenizer.texts_to_sequences(X)

  maxlen = model.layers[0].input_shape[1] # note: may be fragile
  X_token = pad_sequences(X_token, padding='pre', maxlen=maxlen)
  preds = model.predict(X_token).flatten()
  return (preds >= 0.5).astype(int)

predict_pos(movie_df['review'], model)
# Out:
# 39/39 [==============================] - 1s 13ms/step
# array([1, 1, 1, ..., 1, 0, 1])

# %%
# (IN PROGRESS)
# Get the number of positive and negative reviews for each movie
path = "/content/drive/MyDrive/Deep-Learning-Movie-Reviews/2_reviews_per_movie_raw/"
dir_list = os.listdir(path)

print(len(dir_list))
res = []
for fname in dir_list:
  movie_df = pd.read_csv(path + fname)
  preds = predict_pos(movie_df['review'], model)
  res.append({
    "Movie": fname,
    "Positive": np.sum(preds),
    "Negative": len(preds) - np.sum(preds),
    "Mean": np.mean(preds)
  })

# print(res)
pd.DataFrame(res)
# Out:
# 1149
# 39/39 [==============================] - 1s 13ms/step
# 20/20 [==============================] - 0s 14ms/step
# 14/14 [==============================] - 0s 13ms/step
# 9/9 [==============================] - 0s 13ms/step
# 105/105 [==============================] - 1s 13ms/step
# 74/74 [==============================] - 1s 13ms/step
# 15/15 [==============================] - 0s 14ms/step
# 7/7 [==============================] - 0s 13ms/step
# 30/30 [==============================] - 0s 14ms/step
# 12/12 [==============================] - 0s 13ms/step
# 31/31 [==============================] - 0s 14ms/step
# 5/5 [==============================] - 0s 15ms/step
# 45/45 [==============================] - 2s 42ms/step
# 19/19 [==============================] - 0s 13ms/step
# 12/12 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 17ms/step
# 26/26 [==============================] - 0s 14ms/step
# 14/14 [==============================] - 0s 14ms/step
# 17/17 [==============================] - 0s 13ms/step
# 9/9 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 14ms/step
# 37/37 [==============================] - 1s 13ms/step
# 44/44 [==============================] - 1s 14ms/step
# 5/5 [==============================] - 0s 14ms/step
# 20/20 [==============================] - 0s 13ms/step
# 11/11 [==============================] - 0s 13ms/step
# 40/40 [==============================] - 1s 13ms/step
# 19/19 [==============================] - 0s 13ms/step
# 225/225 [==============================] - 3s 13ms/step
# 21/21 [==============================] - 0s 21ms/step
# 6/6 [==============================] - 0s 24ms/step
# 5/5 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 21ms/step
# 76/76 [==============================] - 1s 13ms/step
# 40/40 [==============================] - 1s 13ms/step
# 8/8 [==============================] - 0s 13ms/step
# 17/17 [==============================] - 0s 13ms/step
# 73/73 [==============================] - 1s 13ms/step
# 5/5 [==============================] - 0s 13ms/step
# 17/17 [==============================] - 0s 13ms/step
# 25/25 [==============================] - 0s 14ms/step
# 22/22 [==============================] - 0s 13ms/step
# 22/22 [==============================] - 0s 14ms/step
# 11/11 [==============================] - 0s 13ms/step
# 12/12 [==============================] - 0s 14ms/step
# 53/53 [==============================] - 1s 13ms/step
# 12/12 [==============================] - 0s 13ms/step
# 6/6 [==============================] - 0s 15ms/step
# 6/6 [==============================] - 0s 14ms/step
# 7/7 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 14ms/step
# 16/16 [==============================] - 0s 13ms/step
# 28/28 [==============================] - 0s 13ms/step
# 31/31 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 14ms/step
# 12/12 [==============================] - 0s 14ms/step
# 13/13 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 13ms/step
# 30/30 [==============================] - 0s 14ms/step
# 34/34 [==============================] - 0s 14ms/step
# 7/7 [==============================] - 0s 14ms/step
# 22/22 [==============================] - 0s 13ms/step
# 34/34 [==============================] - 0s 13ms/step
# 24/24 [==============================] - 0s 14ms/step
# 41/41 [==============================] - 1s 13ms/step
# 17/17 [==============================] - 0s 13ms/step
# 11/11 [==============================] - 0s 14ms/step
# 12/12 [==============================] - 0s 13ms/step
# 17/17 [==============================] - 0s 13ms/step
# 11/11 [==============================] - 0s 13ms/step
# 9/9 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 14ms/step
# 19/19 [==============================] - 0s 13ms/step
# 12/12 [==============================] - 0s 14ms/step
# 35/35 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 13ms/step
# 6/6 [==============================] - 0s 15ms/step
# 20/20 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 14ms/step
# 12/12 [==============================] - 0s 13ms/step
# 45/45 [==============================] - 1s 13ms/step
# 26/26 [==============================] - 0s 14ms/step
# 15/15 [==============================] - 0s 14ms/step
# 28/28 [==============================] - 0s 13ms/step
# 52/52 [==============================] - 1s 13ms/step
# 13/13 [==============================] - 0s 13ms/step
# 7/7 [==============================] - 0s 14ms/step
# 43/43 [==============================] - 1s 13ms/step
# 15/15 [==============================] - 0s 14ms/step
# 22/22 [==============================] - 0s 14ms/step
# 7/7 [==============================] - 0s 14ms/step
# 20/20 [==============================] - 0s 13ms/step
# 9/9 [==============================] - 0s 14ms/step
# 17/17 [==============================] - 0s 14ms/step
# 13/13 [==============================] - 0s 13ms/step
# 20/20 [==============================] - 0s 14ms/step
# 25/25 [==============================] - 0s 13ms/step
# 19/19 [==============================] - 0s 14ms/step
# 47/47 [==============================] - 1s 13ms/step
# 11/11 [==============================] - 0s 13ms/step
# 29/29 [==============================] - 0s 14ms/step
# 5/5 [==============================] - 0s 14ms/step
# 10/10 [==============================] - 0s 14ms/step
# 30/30 [==============================] - 0s 14ms/step
# 25/25 [==============================] - 0s 14ms/step
# 20/20 [==============================] - 0s 14ms/step
# 9/9 [==============================] - 0s 13ms/step
# 17/17 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 14ms/step
# 10/10 [==============================] - 0s 14ms/step
# 73/73 [==============================] - 1s 13ms/step
# 11/11 [==============================] - 0s 13ms/step
# 9/9 [==============================] - 0s 13ms/step
# 15/15 [==============================] - 0s 13ms/step
# 48/48 [==============================] - 1s 13ms/step
# 71/71 [==============================] - 1s 14ms/step
# 27/27 [==============================] - 0s 13ms/step
# 26/26 [==============================] - 0s 13ms/step
# 28/28 [==============================] - 0s 13ms/step
# 11/11 [==============================] - 0s 14ms/step
# 29/29 [==============================] - 0s 15ms/step
# 15/15 [==============================] - 0s 14ms/step
# 9/9 [==============================] - 0s 14ms/step
# 19/19 [==============================] - 0s 14ms/step
# 51/51 [==============================] - 1s 13ms/step
# 21/21 [==============================] - 0s 13ms/step
# 22/22 [==============================] - 0s 13ms/step
# 15/15 [==============================] - 0s 14ms/step
# 16/16 [==============================] - 0s 13ms/step
# 30/30 [==============================] - 0s 14ms/step
# 11/11 [==============================] - 0s 14ms/step
# 11/11 [==============================] - 0s 14ms/step
# 56/56 [==============================] - 1s 13ms/step
# 14/14 [==============================] - 0s 14ms/step
# 30/30 [==============================] - 0s 13ms/step
# 19/19 [==============================] - 0s 13ms/step
# 20/20 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 14ms/step
# 14/14 [==============================] - 0s 14ms/step
# 17/17 [==============================] - 0s 13ms/step
# 29/29 [==============================] - 0s 13ms/step
# 10/10 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 13ms/step
# 9/9 [==============================] - 0s 13ms/step
# 18/18 [==============================] - 0s 13ms/step
# 30/30 [==============================] - 0s 14ms/step
# 12/12 [==============================] - 0s 14ms/step
# 114/114 [==============================] - 2s 13ms/step
# 23/23 [==============================] - 0s 13ms/step
# 16/16 [==============================] - 0s 13ms/step
# 11/11 [==============================] - 0s 14ms/step
# 30/30 [==============================] - 0s 13ms/step
# 16/16 [==============================] - 0s 13ms/step
# 14/14 [==============================] - 0s 13ms/step
# 21/21 [==============================] - 0s 14ms/step
# 21/21 [==============================] - 0s 14ms/step
# 14/14 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 14ms/step
# 6/6 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 26/26 [==============================] - 0s 14ms/step
# 38/38 [==============================] - 1s 14ms/step
# 5/5 [==============================] - 0s 14ms/step
# 49/49 [==============================] - 1s 14ms/step
# 5/5 [==============================] - 0s 14ms/step
# 18/18 [==============================] - 0s 14ms/step
# 11/11 [==============================] - 0s 14ms/step
# 41/41 [==============================] - 1s 14ms/step
# 8/8 [==============================] - 0s 15ms/step
# 35/35 [==============================] - 0s 14ms/step
# 72/72 [==============================] - 1s 13ms/step
# 14/14 [==============================] - 0s 13ms/step
# 23/23 [==============================] - 0s 14ms/step
# 17/17 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 15ms/step
# 49/49 [==============================] - 1s 14ms/step
# 5/5 [==============================] - 0s 17ms/step
# 5/5 [==============================] - 0s 14ms/step
# 27/27 [==============================] - 0s 13ms/step
# 81/81 [==============================] - 1s 14ms/step
# 29/29 [==============================] - 0s 15ms/step
# 52/52 [==============================] - 1s 14ms/step
# 18/18 [==============================] - 0s 13ms/step
# 7/7 [==============================] - 0s 13ms/step
# 13/13 [==============================] - 0s 13ms/step
# 18/18 [==============================] - 0s 13ms/step
# 10/10 [==============================] - 0s 13ms/step
# 38/38 [==============================] - 1s 13ms/step
# 24/24 [==============================] - 0s 14ms/step
# 31/31 [==============================] - 0s 13ms/step
# 45/45 [==============================] - 1s 13ms/step
# 10/10 [==============================] - 0s 15ms/step
# 9/9 [==============================] - 0s 14ms/step
# 31/31 [==============================] - 0s 13ms/step
# 11/11 [==============================] - 0s 14ms/step
# 11/11 [==============================] - 0s 13ms/step
# 6/6 [==============================] - 0s 14ms/step
# 33/33 [==============================] - 0s 13ms/step
# 22/22 [==============================] - 0s 13ms/step
# 13/13 [==============================] - 0s 14ms/step
# 13/13 [==============================] - 0s 15ms/step
# 22/22 [==============================] - 0s 14ms/step
# 45/45 [==============================] - 1s 13ms/step
# 17/17 [==============================] - 0s 13ms/step
# 24/24 [==============================] - 0s 14ms/step
# 5/5 [==============================] - 0s 14ms/step
# 30/30 [==============================] - 0s 13ms/step
# 28/28 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 14ms/step
# 27/27 [==============================] - 0s 14ms/step
# 10/10 [==============================] - 0s 14ms/step
# 44/44 [==============================] - 1s 14ms/step
# 19/19 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 13ms/step
# 14/14 [==============================] - 0s 13ms/step
# 39/39 [==============================] - 1s 13ms/step
# 66/66 [==============================] - 1s 13ms/step
# 21/21 [==============================] - 0s 14ms/step
# 10/10 [==============================] - 0s 14ms/step
# 30/30 [==============================] - 0s 14ms/step
# 45/45 [==============================] - 1s 14ms/step
# 8/8 [==============================] - 0s 13ms/step
# 7/7 [==============================] - 0s 14ms/step
# 62/62 [==============================] - 1s 13ms/step
# 13/13 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 14ms/step
# 5/5 [==============================] - 0s 14ms/step
# 7/7 [==============================] - 0s 17ms/step
# 5/5 [==============================] - 0s 15ms/step
# 27/27 [==============================] - 0s 14ms/step
# 12/12 [==============================] - 0s 14ms/step
# 38/38 [==============================] - 1s 13ms/step
# 13/13 [==============================] - 0s 14ms/step
# 16/16 [==============================] - 0s 13ms/step
# 14/14 [==============================] - 0s 13ms/step
# 21/21 [==============================] - 0s 13ms/step
# 97/97 [==============================] - 1s 13ms/step
# 14/14 [==============================] - 0s 13ms/step
# 49/49 [==============================] - 1s 13ms/step
# 50/50 [==============================] - 1s 13ms/step
# 26/26 [==============================] - 0s 15ms/step
# 7/7 [==============================] - 0s 14ms/step
# 33/33 [==============================] - 0s 13ms/step
# 33/33 [==============================] - 0s 14ms/step
# 5/5 [==============================] - 0s 14ms/step
# 9/9 [==============================] - 0s 14ms/step
# 55/55 [==============================] - 1s 14ms/step
# 20/20 [==============================] - 0s 20ms/step
# 5/5 [==============================] - 0s 21ms/step
# 21/21 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 21ms/step
# 6/6 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 21ms/step
# 20/20 [==============================] - 0s 13ms/step
# 9/9 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 13/13 [==============================] - 0s 14ms/step
# 14/14 [==============================] - 0s 15ms/step
# 12/12 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 14ms/step
# 16/16 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 5/5 [==============================] - 0s 14ms/step
# 25/25 [==============================] - 0s 15ms/step
# 20/20 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 14ms/step
# 24/24 [==============================] - 0s 13ms/step
# 27/27 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 13ms/step
# 49/49 [==============================] - 1s 13ms/step
# 17/17 [==============================] - 0s 13ms/step
# 6/6 [==============================] - 0s 14ms/step
# 15/15 [==============================] - 0s 14ms/step
# 57/57 [==============================] - 1s 14ms/step
# 60/60 [==============================] - 1s 13ms/step
# 30/30 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 13ms/step
# 42/42 [==============================] - 1s 13ms/step
# 9/9 [==============================] - 0s 14ms/step
# 122/122 [==============================] - 2s 13ms/step
# 10/10 [==============================] - 0s 13ms/step
# 18/18 [==============================] - 0s 14ms/step
# 41/41 [==============================] - 1s 13ms/step
# 28/28 [==============================] - 0s 13ms/step
# 23/23 [==============================] - 0s 13ms/step
# 29/29 [==============================] - 0s 14ms/step
# 12/12 [==============================] - 0s 13ms/step
# 32/32 [==============================] - 0s 13ms/step
# 116/116 [==============================] - 2s 13ms/step
# 15/15 [==============================] - 0s 14ms/step
# 34/34 [==============================] - 0s 13ms/step
# 28/28 [==============================] - 0s 14ms/step
# 7/7 [==============================] - 0s 14ms/step
# 22/22 [==============================] - 0s 13ms/step
# 40/40 [==============================] - 1s 13ms/step
# 32/32 [==============================] - 0s 13ms/step
# 7/7 [==============================] - 0s 14ms/step
# 27/27 [==============================] - 0s 13ms/step
# 38/38 [==============================] - 1s 14ms/step
# 9/9 [==============================] - 0s 14ms/step
# 314/314 [==============================] - 4s 14ms/step
# 37/37 [==============================] - 1s 13ms/step
# 7/7 [==============================] - 0s 14ms/step
# 63/63 [==============================] - 1s 13ms/step
# 48/48 [==============================] - 1s 13ms/step
# 4/4 [==============================] - 0s 15ms/step
# 34/34 [==============================] - 0s 13ms/step
# 29/29 [==============================] - 0s 14ms/step
# 17/17 [==============================] - 0s 14ms/step
# 10/10 [==============================] - 0s 13ms/step
# 17/17 [==============================] - 0s 13ms/step
# 29/29 [==============================] - 0s 13ms/step
# 10/10 [==============================] - 0s 14ms/step
# 69/69 [==============================] - 1s 13ms/step
# 11/11 [==============================] - 0s 13ms/step
# 15/15 [==============================] - 0s 14ms/step
# 7/7 [==============================] - 0s 15ms/step
# 12/12 [==============================] - 0s 14ms/step
# 22/22 [==============================] - 0s 14ms/step
# 31/31 [==============================] - 0s 14ms/step
# 5/5 [==============================] - 0s 14ms/step
# 33/33 [==============================] - 0s 14ms/step
# 55/55 [==============================] - 1s 14ms/step
# 14/14 [==============================] - 0s 13ms/step
# 22/22 [==============================] - 0s 14ms/step
# 7/7 [==============================] - 0s 14ms/step
# 9/9 [==============================] - 0s 14ms/step
# 21/21 [==============================] - 0s 14ms/step
# 9/9 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 19/19 [==============================] - 0s 14ms/step
# 28/28 [==============================] - 0s 13ms/step
# 13/13 [==============================] - 0s 15ms/step
# 32/32 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 15ms/step
# 18/18 [==============================] - 0s 14ms/step
# 27/27 [==============================] - 0s 14ms/step
# 30/30 [==============================] - 0s 14ms/step
# 5/5 [==============================] - 0s 15ms/step
# 30/30 [==============================] - 0s 13ms/step
# 71/71 [==============================] - 1s 13ms/step
# 68/68 [==============================] - 1s 13ms/step
# 7/7 [==============================] - 0s 13ms/step
# 26/26 [==============================] - 0s 13ms/step
# 36/36 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 13ms/step
# 29/29 [==============================] - 0s 13ms/step
# 62/62 [==============================] - 1s 13ms/step
# 16/16 [==============================] - 0s 14ms/step
# 18/18 [==============================] - 0s 13ms/step
# 7/7 [==============================] - 0s 13ms/step
# 48/48 [==============================] - 1s 14ms/step
# 25/25 [==============================] - 0s 14ms/step
# 62/62 [==============================] - 1s 13ms/step
# 30/30 [==============================] - 0s 13ms/step
# 40/40 [==============================] - 1s 13ms/step
# 37/37 [==============================] - 1s 14ms/step
# 16/16 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 36/36 [==============================] - 0s 13ms/step
# 13/13 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 18ms/step
# 17/17 [==============================] - 0s 14ms/step
# 18/18 [==============================] - 0s 13ms/step
# 14/14 [==============================] - 0s 14ms/step
# 5/5 [==============================] - 0s 14ms/step
# 24/24 [==============================] - 0s 14ms/step
# 5/5 [==============================] - 0s 14ms/step
# 16/16 [==============================] - 0s 16ms/step
# 7/7 [==============================] - 0s 14ms/step
# 14/14 [==============================] - 0s 14ms/step
# 12/12 [==============================] - 0s 14ms/step
# 21/21 [==============================] - 0s 14ms/step
# 15/15 [==============================] - 0s 14ms/step
# 19/19 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 5/5 [==============================] - 0s 21ms/step
# 25/25 [==============================] - 1s 22ms/step
# 4/4 [==============================] - 0s 23ms/step
# 70/70 [==============================] - 1s 18ms/step
# 24/24 [==============================] - 0s 14ms/step
# 81/81 [==============================] - 1s 14ms/step
# 4/4 [==============================] - 0s 14ms/step
# 24/24 [==============================] - 0s 14ms/step
# 10/10 [==============================] - 0s 14ms/step
# 18/18 [==============================] - 0s 13ms/step
# 16/16 [==============================] - 0s 13ms/step
# 25/25 [==============================] - 0s 14ms/step
# 11/11 [==============================] - 0s 13ms/step
# 86/86 [==============================] - 1s 14ms/step
# 5/5 [==============================] - 0s 15ms/step
# 21/21 [==============================] - 0s 14ms/step
# 6/6 [==============================] - 0s 14ms/step
# 6/6 [==============================] - 0s 14ms/step
# 27/27 [==============================] - 0s 13ms/step
# 13/13 [==============================] - 0s 15ms/step
# 37/37 [==============================] - 1s 13ms/step
# 4/4 [==============================] - 0s 14ms/step
# 44/44 [==============================] - 1s 14ms/step
# 46/46 [==============================] - 1s 13ms/step
# 38/38 [==============================] - 1s 13ms/step
# 13/13 [==============================] - 0s 14ms/step
# 18/18 [==============================] - 0s 14ms/step
# 65/65 [==============================] - 1s 14ms/step
# 14/14 [==============================] - 0s 14ms/step
# 7/7 [==============================] - 0s 14ms/step
# 12/12 [==============================] - 0s 14ms/step
# 26/26 [==============================] - 0s 14ms/step
# 13/13 [==============================] - 0s 14ms/step
# 21/21 [==============================] - 0s 14ms/step
# 6/6 [==============================] - 0s 15ms/step
# 17/17 [==============================] - 0s 13ms/step
# 7/7 [==============================] - 0s 14ms/step
# 18/18 [==============================] - 0s 14ms/step
# 24/24 [==============================] - 0s 13ms/step
# 29/29 [==============================] - 0s 13ms/step
# 20/20 [==============================] - 0s 14ms/step
# 12/12 [==============================] - 0s 15ms/step
# 74/74 [==============================] - 1s 13ms/step
# 11/11 [==============================] - 0s 13ms/step
# 10/10 [==============================] - 0s 14ms/step
# 14/14 [==============================] - 0s 13ms/step
# 17/17 [==============================] - 0s 13ms/step
# 11/11 [==============================] - 0s 14ms/step
# 24/24 [==============================] - 0s 14ms/step
# 7/7 [==============================] - 0s 14ms/step
# 56/56 [==============================] - 1s 13ms/step
# 6/6 [==============================] - 0s 14ms/step
# 15/15 [==============================] - 0s 16ms/step
# 10/10 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 14/14 [==============================] - 0s 14ms/step
# 29/29 [==============================] - 0s 13ms/step
# 12/12 [==============================] - 0s 14ms/step
# 5/5 [==============================] - 0s 14ms/step
# 28/28 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 15ms/step
# 24/24 [==============================] - 0s 13ms/step
# 21/21 [==============================] - 0s 13ms/step
# 10/10 [==============================] - 0s 13ms/step
# 10/10 [==============================] - 0s 14ms/step
# 60/60 [==============================] - 1s 13ms/step
# 6/6 [==============================] - 0s 14ms/step
# 33/33 [==============================] - 0s 14ms/step
# 27/27 [==============================] - 0s 13ms/step
# 31/31 [==============================] - 0s 14ms/step
# 10/10 [==============================] - 0s 14ms/step
# 16/16 [==============================] - 0s 13ms/step
# 21/21 [==============================] - 0s 13ms/step
# 24/24 [==============================] - 0s 14ms/step
# 19/19 [==============================] - 0s 14ms/step
# 32/32 [==============================] - 0s 14ms/step
# 14/14 [==============================] - 0s 13ms/step
# 59/59 [==============================] - 1s 14ms/step
# 9/9 [==============================] - 0s 13ms/step
# 6/6 [==============================] - 0s 14ms/step
# 37/37 [==============================] - 1s 14ms/step
# 5/5 [==============================] - 0s 14ms/step
#
[==============================] - 0s 14ms/step
# 15/15 [==============================] - 0s 15ms/step
# 35/35 [==============================] - 1s 15ms/step
# 132/132 [==============================] - 2s 14ms/step
# 17/17 [==============================] - 0s 14ms/step
# 36/36 [==============================] - 1s 14ms/step
# 5/5 [==============================] - 0s 15ms/step
# 36/36 [==============================] - 1s 14ms/step
# 87/87 [==============================] - 1s 14ms/step
# 9/9 [==============================] - 0s 14ms/step
# 15/15 [==============================] - 0s 15ms/step
# 40/40 [==============================] - 1s 14ms/step
# 5/5 [==============================] - 0s 15ms/step
# 44/44 [==============================] - 1s 14ms/step
# 100/100 [==============================] - 1s 14ms/step
# 6/6 [==============================] - 0s 15ms/step
# 23/23 [==============================] - 0s 15ms/step
# 48/48 [==============================] - 1s 14ms/step
# 73/73 [==============================] - 1s 15ms/step
# 7/7 [==============================] - 0s 15ms/step
# 7/7 [==============================] - 0s 14ms/step
# 14/14 [==============================] - 0s 15ms/step
# 27/27 [==============================] - 0s 14ms/step
# 18/18 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 15ms/step
# 17/17 [==============================] - 0s 15ms/step
# 18/18 [==============================] - 0s 15ms/step
# 15/15 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 11/11 [==============================] - 0s 17ms/step
# 28/28 [==============================] - 0s 14ms/step
# 20/20 [==============================] - 0s 15ms/step
# 27/27 [==============================] - 0s 14ms/step
# 39/39 [==============================] - 1s 14ms/step
# 30/30 [==============================] - 0s 15ms/step
# 28/28 [==============================] - 0s 14ms/step
# 5/5 [==============================] - 0s 15ms/step
# 14/14 [==============================] - 0s 16ms/step
# 44/44 [==============================] - 1s 14ms/step
# 24/24 [==============================] - 0s 15ms/step
# 19/19 [==============================] - 0s 15ms/step
# 17/17 [==============================] - 0s 15ms/step
# 18/18 [==============================] - 0s 14ms/step
# 7/7 [==============================] - 0s 15ms/step
# 20/20 [==============================] - 0s 14ms/step
# 7/7 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 15ms/step
#                                     Movie  Positive  Negative      Mean
# 0                     Braveheart 1995.csv       895       344  0.722357
# 1                 Bruce Almighty 2003.csv       376       262  0.589342
# 2                         Capote 2005.csv       303       145  0.676339
# 3                     Caddyshack 1980.csv       173       105  0.622302
# 4              Bohemian Rhapsody 2018.csv      2399       933  0.719988
# ...                                   ...       ...       ...       ...
# 1144                 Bridesmaids 2011.csv       289       274  0.513321
# 1145                        Bolt 2008.csv       159        55  0.742991
# 1146          Burn After Reading 2008.csv       308       314  0.495177
# 1147  Born on the Fourth of July 1989.csv       137        66  0.674877
# 1148                   Burlesque 2010.csv       150       102  0.595238
#
# [1149 rows x 4 columns]

# %%
pd.DataFrame(res).to_csv('/content/drive/MyDrive/Deep-Learning-Movie-Reviews/model-outputs/model11292022.csv', mode='a', header=True)

# %%
# (uncomment if running at a later time)
# res = pd.read_csv('/content/drive/MyDrive/Deep-Learning-Movie-Reviews/model-outputs/model11292022.csv')

# %%
path = "/content/drive/MyDrive/Deep-Learning-Movie-Reviews/1_movies_per_genre/"
genres_list = os.listdir(path)
movies_df = pd.DataFrame()
for fname in genres_list:
  movie_df = pd.read_csv(path + fname)
  movies_df = pd.concat([movies_df, movie_df])

movies_df
# Out:
#                                                  name  year movie_rated  \
# 0                                     The Dark Knight  2008       PG-13
# 1                                           Inception  2010       PG-13
# 2                                          The Matrix  1999           R
# 3   The Lord of the Rings: The Fellowship of the Ring  2001       PG-13
# 4                               The Dark Knight Rises  2012       PG-13
# ..                                                ...   ...         ...
# 95                                       Spider-Man 2  2004       PG-13
# 96           Harry Potter and the Prisoner of Azkaban  2004          PG
# 97                Harry Potter and the Goblet of Fire  2005       PG-13
# 98                                   Independence Day  1996       PG-13
# 99                                        Toy Story 2  1999           G
#
#    run_length                          genres            release_date  rating  \
# 0    2h 32min          Action; Crime; Drama;       18 July 2008 (USA)     9.0
# 1    2h 28min     Action; Adventure; Sci-Fi;       16 July 2010 (USA)     8.8
# 2    2h 16min                Action; Sci-Fi;      31 March 1999 (USA)     8.7
# 3    2h 58min      Action; Adventure; Drama;   19 December 2001 (USA)     8.8
# 4    2h 44min             Action; Adventure;       20 July 2012 (USA)     8.4
# ..        ...                             ...                     ...     ...
# 95    2h 7min     Action; Adventure; Sci-Fi;       30 June 2004 (USA)     7.3
# 96   2h 22min            Adventure; Fantasy;        4 June 2004 (USA)     7.9
# 97   2h 37min            Adventure; Fantasy;   18 November 2005 (USA)     7.7
# 98   2h 25min     Action; Adventure; Sci-Fi;        3 July 1996 (USA)     7.0
# 99   1h 32min  Animation; Adventure; Comedy;   24 November 1999 (USA)     7.9
#
#     num_raters  num_reviews                                         review_url
# 0      2224522         6836  https://www.imdb.com/title/tt0468569/reviews/_...
# 1      1981675         3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 2      1619761         4281  https://www.imdb.com/title/tt0133093/reviews/_...
# 3      1609165         5365  https://www.imdb.com/title/tt0120737/reviews/_...
# 4      1470329         2979  https://www.imdb.com/title/tt1345836/reviews/_...
# ..         ...          ...                                                ...
# 95      529344         1450  https://www.imdb.com/title/tt0316654/reviews/_...
# 96      528503         1592  https://www.imdb.com/title/tt0304141/reviews/_...
# 97      526115         1980  https://www.imdb.com/title/tt0330373/reviews/_...
# 98      516789          939  https://www.imdb.com/title/tt0116629/reviews/_...
# 99      511239          611  https://www.imdb.com/title/tt0120363/reviews/_...
#
# [1700 rows x 10 columns]

# %%
review_counts = pd.DataFrame(res)

# %%
# add a column for which csv of reviews correspond to the given movie
movies_df['reviews_csv'] = movies_df['name'] + ' ' + movies_df['year'].astype(str) + '.csv'

# left join review counts to movie info
movies_df = movies_df.set_index('reviews_csv').join(pd.DataFrame(res).set_index('Movie'))

movies_df
# Out:
#                                                            name  year  \
# 10 Cloverfield Lane 2016.csv                10 Cloverfield Lane  2016
# 10 Cloverfield Lane 2016.csv                10 Cloverfield Lane  2016
# 10 Things I Hate About You 1999.csv  10 Things I Hate About You  1999
# 12 Angry Men 1957.csv                              12 Angry Men  1957
# 12 Angry Men 1957.csv                              12 Angry Men  1957
# ...                                                         ...   ...
# Zombieland 2009.csv                                  Zombieland  2009
# Zombieland 2009.csv                                  Zombieland  2009
# Zootopia 2016.csv                                      Zootopia  2016
# Zootopia 2016.csv                                      Zootopia  2016
# Zulu 1964.csv                                              Zulu  1964
#
#                                     movie_rated run_length  \
# 10 Cloverfield Lane 2016.csv              PG-13   1h 43min
# 10 Cloverfield Lane 2016.csv              PG-13   1h 43min
# 10 Things I Hate About You 1999.csv       PG-13   1h 37min
# 12 Angry Men 1957.csv                  Approved   1h 36min
# 12 Angry Men 1957.csv                  Approved   1h 36min
# ...                                         ...        ...
# Zombieland 2009.csv                           R   1h 28min
# Zombieland 2009.csv                           R   1h 28min
# Zootopia 2016.csv                            PG   1h 48min
# Zootopia 2016.csv                            PG   1h 48min
# Zulu 1964.csv                         Not Rated   2h 18min
#
#                                                              genres  \
# 10 Cloverfield Lane 2016.csv               Drama; Horror; Mystery;
# 10 Cloverfield Lane 2016.csv               Drama; Horror; Mystery;
# 10 Things I Hate About You 1999.csv               Comedy; Romance;
# 12 Angry Men 1957.csv                                Crime; Drama;
# 12 Angry Men 1957.csv                                Crime; Drama;
# ...                                                             ...
# Zombieland 2009.csv                                        Comedy;
# Zombieland 2009.csv                    Adventure; Comedy; Fantasy;
# Zootopia 2016.csv                    Animation; Adventure; Comedy;
# Zootopia 2016.csv                                          Comedy;
# Zulu 1964.csv                                 Drama; History; War;
#
#                                              release_date  rating  num_raters  \
# 10 Cloverfield Lane 2016.csv          11 March 2016 (USA)     7.2      280919
# 10 Cloverfield Lane 2016.csv          11 March 2016 (USA)     7.2      280920
# 10 Things I Hate About You 1999.csv   31 March 1999 (USA)     7.3      287665
# 12 Angry Men 1957.csv                 10 April 1957 (USA)     8.9      661761
# 12 Angry Men 1957.csv                 10 April 1957 (USA)     8.9      661761
# ...                                                   ...     ...         ...
# Zombieland 2009.csv                  2 October 2009 (USA)     7.6      507445
# Zombieland 2009.csv                  2 October 2009 (USA)     7.6      507361
# Zootopia 2016.csv                      4 March 2016 (USA)     8.0      417226
# Zootopia 2016.csv                      4 March 2016 (USA)     8.0      417325
# Zulu 1964.csv                          17 June 1964 (USA)     7.7       34911
#
#                                      num_reviews  \
# 10 Cloverfield Lane 2016.csv                 752
# 10 Cloverfield Lane 2016.csv                 752
# 10 Things I Hate About You 1999.csv          616
# 12 Angry Men 1957.csv                       1575
# 12 Angry Men 1957.csv                       1575
# ...                                          ...
# Zombieland 2009.csv                          712
# Zombieland 2009.csv                          713
# Zootopia 2016.csv                            710
# Zootopia 2016.csv                            711
# Zulu 1964.csv                                263
#
#                                                                             review_url  \
# 10 Cloverfield Lane 2016.csv         https://www.imdb.com/title/tt1179933/reviews/_...
# 10 Cloverfield Lane 2016.csv         https://www.imdb.com/title/tt1179933/reviews/_...
# 10 Things I Hate About You 1999.csv  https://www.imdb.com/title/tt0147800/reviews/_...
# 12 Angry Men 1957.csv                https://www.imdb.com/title/tt0050083/reviews/_...
# 12 Angry Men 1957.csv                https://www.imdb.com/title/tt0050083/reviews/_...
# ...                                                                                ...
# Zombieland 2009.csv                  https://www.imdb.com/title/tt1156398/reviews/_...
# Zombieland 2009.csv                  https://www.imdb.com/title/tt1156398/reviews/_...
# Zootopia 2016.csv                    https://www.imdb.com/title/tt2948356/reviews/_...
# Zootopia 2016.csv                    https://www.imdb.com/title/tt2948356/reviews/_...
# Zulu 1964.csv                        https://www.imdb.com/title/tt0058777/reviews/_...
#
#                                      Unnamed: 0  Positive  Negative      Mean
# 10 Cloverfield Lane 2016.csv             1004.0     438.0     314.0  0.582447
# 10 Cloverfield Lane 2016.csv             1004.0     438.0     314.0  0.582447
# 10 Things I Hate About You 1999.csv      1008.0     414.0     197.0  0.677578
# 12 Angry Men 1957.csv                    1009.0    1076.0     435.0  0.712111
# 12 Angry Men 1957.csv                    1009.0    1076.0     435.0  0.712111
# ...                                         ...       ...       ...       ...
# Zombieland 2009.csv                       990.0     403.0     310.0  0.565217
# Zombieland 2009.csv                       990.0     403.0     310.0  0.565217
# Zootopia 2016.csv                         998.0     516.0     185.0  0.736091
# Zootopia 2016.csv                         998.0     516.0     185.0  0.736091
# Zulu 1964.csv                             999.0     185.0      76.0  0.708812
#
# [1700 rows x 14 columns]

# %%
# There are missing values!
# TODO: figure out why this is
movies_df['Positive'].isnull().sum()
# Out:
# 186

# %%
movies_df.describe()
# Out:
#               year       rating    num_raters   num_reviews   Unnamed: 0  \
# count  1700.000000  1700.000000  1.700000e+03   1700.000000  1514.000000
# mean   2002.798235     7.457706  4.134152e+05   1003.601176   566.221929
# std      14.359010     0.736682  3.277902e+05   1045.584805   332.110515
# min    1915.000000     3.500000  1.929000e+04    102.000000     0.000000
# 25%    1999.000000     7.000000  1.812258e+05    393.750000   277.000000
# 50%    2006.000000     7.600000  3.445890e+05    719.500000   563.500000
# 75%    2012.000000     8.000000  5.722170e+05   1256.500000   857.000000
# max    2020.000000     9.300000  2.258845e+06  10279.000000  1148.000000
#
#           Positive     Negative         Mean
# count  1514.000000  1514.000000  1514.000000
# mean    554.826288   354.690885     0.626664
# std     540.314370   375.169224     0.092259
# min      58.000000    19.000000     0.327899
# 25%     231.750000   127.000000     0.560477
# 50%     431.500000   249.000000     0.637614
# 75%     715.750000   430.000000     0.698265
# max    6527.000000  3519.000000     0.829268

# %%
import seaborn as sb
import matplotlib.pyplot as plt

sb.regplot(x = "Mean", y = "rating", ci = None, data = movies_df)

# %%
import statsmodels.formula.api as smf
reg = smf.ols('Mean ~ rating', data = movies_df).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Mean   R-squared:                       0.414
# Model:                            OLS   Adj. R-squared:                  0.413
# Method:                 Least Squares   F-statistic:                     1067.
# Date:                Wed, 07 Dec 2022   Prob (F-statistic):          1.34e-177
# Time:                        03:17:42   Log-Likelihood:                 1864.7
# No. Observations:                1514   AIC:                            -3725.
# Df Residuals:                    1512   BIC:                            -3715.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0120      0.019      0.634      0.526      -0.025       0.049
# rating         0.0824      0.003     32.672      0.000       0.077       0.087
# ==============================================================================
# Omnibus:                        2.045   Durbin-Watson:                   1.368
# Prob(Omnibus):                  0.360   Jarque-Bera (JB):                2.003
# Skew:                          -0.089   Prob(JB):                        0.367
# Kurtosis:                       3.014   Cond. No.                         79.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sb.regplot(x = "Positive", y = "Negative", ci = None, data = movies_df)

# %%
sb.regplot(x = "year", y = "rating", ci = None, data = movies_df)
